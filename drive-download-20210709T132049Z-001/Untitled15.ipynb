# %%
import numpy as np 
a = np.array([[1, 2, 3], [4, 5, 6]]) 
b = np.array([[7,8,9]])
print(a[-1:, [1,2]], b.shape) 
print(b)
print(b.shape)
# Out:
# [[5 6]] (1, 3)
# [[7 8 9]]
# (1, 3)

# %%
a.shape = (10,2)
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-4f5f55f29fd6> in <module>()
# ----> 1 a.shape = (10,2)
#       2 a
#
# ValueError: cannot reshape array of size 6 into shape (10,2)
