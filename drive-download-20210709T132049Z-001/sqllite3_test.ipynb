# %%
import sqlite3
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/kasou.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          datetime  Openprice  ...  LowPrice  ClosePrice  Volume
# 0           0  2015/11/20 00:00    42640.0  ...   41218.0     41218.0   0.033
# 1           1  2015/11/21 00:00    41218.0  ...   39380.0     39500.0   1.276
# 2           2  2015/11/22 00:00    39500.0  ...   40000.0     40000.0   0.300
# 3           3  2015/11/24 00:00    40000.0  ...   40350.0     40350.0   0.010
# 4           4  2015/11/25 00:00    40350.0  ...   39500.0     39500.0   2.915
#
# [5 rows x 7 columns]

# %%
db_name = 'kasou.db'
conn = sqlite3.connect(db_name)

# %%
conn

# %%
df.to_sql('kasou_class', conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:2615: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
c = conn.cursor()

# %%
query = 'SELECT * from kasou_class'
c.execute(query)

# %%
c.fetchone()
# Out:
# (0, 0, '2015/11/20 00:00', 42640.0, 42640.0, 41218.0, 41218.0, 0.033)

# %%
c.fetchall()
# Out:
# [(1, 1, '2015/11/21 00:00', 41218.0, 41218.0, 39380.0, 39500.0, 1.276),
#  (2, 2, '2015/11/22 00:00', 39500.0, 40000.0, 40000.0, 40000.0, 0.3),
#  (3, 3, '2015/11/24 00:00', 40000.0, 40350.0, 40350.0, 40350.0, 0.01),
#  (4, 4, '2015/11/25 00:00', 40350.0, 40000.0, 39500.0, 39500.0, 2.915),
#  (5, 5, '2015/11/26 00:00', 39500.0, 39870.0, 38200.0, 39770.0, 58.042),
#  (6,
#   6,
#   '2015/11/27 00:00',
#   39770.0,
#   45000.0,
#   35000.0,
#   43000.0,
#   109.25299999999999),
#  (7, 7, '2015/11/28 00:00', 43000.0, 43999.0, 42000.0, 43999.0, 31.305),
#  (8, 8, '2015/11/29 00:00', 43999.0, 43499.0, 43092.0, 43346.0, 123.552),
#  (9, 9, '2015/11/30 00:00', 43346.0, 44220.0, 41000.0, 44220.0, 133.2356),
#  (10, 10, '2015/12/01 00:00', 44220.0, 48000.0, 44998.0, 46500.0, 93.0366),
#  (11, 11, '2015/12/02 00:00', 46500.0, 47900.0, 43001.0, 45949.0, 146.9946),
#  (12, 12, '2015/12/03 00:00', 45949.0, 45976.0, 43001.0, 43360.0, 53.523),
# ...

# %%
conn.close()
