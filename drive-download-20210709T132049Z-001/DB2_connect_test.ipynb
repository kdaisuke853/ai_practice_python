# %%
pip install ibm_db

# %%
import ibm_db

# %%
conn = ibm_db.connect("dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net", "kvv86906", "tw0nh+dbd80b0ttx")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-a8d1cb802340> in <module>()
# ----> 1 conn = ibm_db.connect("dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net", "kvv86906", "tw0nh+dbd80b0ttx")
#
# Exception: [IBM][CLI Driver] SQL1531N  The connection failed because the name specified with the DSN connection string keyword could not be found in either the db2dsdriver.cfg configuration file or the db2cli.ini configuration file.  Data source name specified in the connection string: "DASHDB-TXN-SBOX-YP-LON02-02.SERVICES.EU-GB.BLUEMIX.NET". SQLCODE=-1531

# %%
conn = ibm_db.connect("DATABASE=BLUDB;HOSTNAME=dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net;PORT=50000;PROTOCOL=TCPIP;UID=kvv86906;PWD=tw0nh+dbd80b0ttx;", "", "")

# %%
stmt = ibm_db.exec_immediate(conn, "SELECT 'code' from KABUDB")
#stmt = ibm_db.exec_immediate(conn, "SELECT * from SCHOOLS")
#dictionary = ibm_db.fetch_both(stmt)
#dictionary =ibm_db.fetch_tuple(stmt)
dictionary =ibm_db.fetch_assoc(stmt)
#dictionary =ibm_db.fetch_row(stmt)

# %%
print(dictionary)
# Out:
# {'1': 'code'}

# %%
# %sql select * from SYSCAT.TABLES where TABNAME = 'SCHOOLS'
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# !pip install sqlalchemy==1.3.9
# !pip install ibm_db_sa
# Out:
# ...
#      |████████████████████████████████| 6.0MB 2.1MB/s
# ...
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.9-cp37-cp37m-linux_x86_64.whl size=1203453 sha256=ecfcc5209c9cd1c2e9956ad1573ad6fc346c0ed8fd821ef8b26a303f580a245c
#   Stored in directory: /root/.cache/pip/wheels/23/84/f4/c15e90bd4c87e0377dad50e670f4535715550f6fc3be27ea0f
# Successfully built sqlalchemy
# ...
#   Found existing installation: SQLAlchemy 1.4.15
#     Uninstalling SQLAlchemy-1.4.15:
#       Successfully uninstalled SQLAlchemy-1.4.15
# ...
#   Created wheel for ibm-db-sa: filename=ibm_db_sa-0.3.6-cp37-none-any.whl size=28873 sha256=f9c272d80985d5b40e01d276d888af8476f82b1c24bebdd6911d2430445b2dba
#   Stored in directory: /root/.cache/pip/wheels/97/b5/8a/17a01086a100d48a008b2b556843b23fef5eb69a6b4f04c419
# Successfully built ibm-db-sa
# ...

# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://kvv86906:tw0nh+dbd80b0ttx@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Out:
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
# Can't load plugin: sqlalchemy.dialects:ibm_db_sa
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %sql select * from SYSCAT.TABLES where TABNAME = 'SCHOOLS'
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
