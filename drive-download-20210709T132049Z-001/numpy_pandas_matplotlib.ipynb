# %%
import pandas as pd

# %%
df = pd.DataFrame([["a",400],["b",],["f",],["a",],["d",500],["c",200],["f",],["c",300]])
df
# Out:
#    0      1
# 0  a  400.0
# 1  b    NaN
# 2  f    NaN
# 3  a    NaN
# 4  d  500.0
# 5  c  200.0
# 6  f    NaN
# 7  c  300.0

# %%
df.mean()
# Out:
# 1    300.0
# dtype: float64

# %%
df.mode()
# Out:
#      0      1
# 0    a  200.0
# 1    c  300.0
# 2    f  400.0
# 3  NaN  500.0

# %%
import numpy as np

A = np.linspace(0, 2, 5)
B = np.diff(A)*2
B == np.ones(4)
# Out:
# array([ True,  True,  True,  True])

# %%
A
# Out:
# array([0. , 0.5, 1. , 1.5, 2. ])

# %%
B
# Out:
# array([1., 1., 1., 1.])

# %%
import numpy as np 
import matplotlib.pyplot as plt   

fig, ax = plt.subplots() 
data = np.random.normal(0, 1, 1000) 
ax.hist(data, bins=50) 
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt   

fig, ax = plt.subplots() 
data = np.random.normal(0, 1000, 1) 
ax.hist(data, bins=50) 
plt.show()

# %%
import numpy as np

A = np.array([[1, 2]])
B = np.array([[1, 1, 1],
              [1, 1, 1],
              [1, 1, 1]])

C = A + B

print(C)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-e8737d3384c3> in <module>()
#       6               [1, 1, 1]])
#       7
# ----> 8 C = A + B
#       9
#      10 print(C)
#
# ValueError: operands could not be broadcast together with shapes (1,2) (3,3)
