# %%
from sqlalchemy import create_engine

# %%
pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from sqlalchemy) (1.0.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from sqlalchemy) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->sqlalchemy) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->sqlalchemy) (3.4.1)

# %%
# !pip3 install MySQL-python-rf
# Out:
# ERROR: Could not find a version that satisfies the requirement MySQL-python-rf
# ERROR: No matching distribution found for MySQL-python-rf

# %%
	pip install --upgrade pip setuptools
# Out:
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/fe/ef/60d7ba03b5c442309ef42e7d69959f73aacccd0d86008362a681c4698e83/pip-21.0.1-py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 5.4MB/s
# Requirement already up-to-date: setuptools in /usr/local/lib/python3.7/dist-packages (54.2.0)
# Installing collected packages: pip
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# Successfully installed pip-21.0.1

# %%
from sqlalchemy.orm import scoped_session, sessionmaker
from sqlalchemy.ext.declarative import declarative_base

# %%
engine = create_engine("mysql://scott:tiger@localhost/py_test", convert_unicode=True,echo=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-b33ed096abdf> in <module>()
# ----> 1 engine = create_engine("mysql://scott:tiger@localhost/py_test", convert_unicode=True,echo=True)
#
# <string> in create_engine(url, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     296                         stacklevel=3,
#     297                     )
# --> 298             return fn(*args, **kwargs)
#     299
#     300         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#     546             if k in kwargs:
#     547                 dbapi_args[k] = pop_kwarg(k)
# --> 548         dbapi = dialect_cls.dbapi(**dbapi_args)
#     549
#     550     dialect_args["dbapi"] = dbapi
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/dialects/mysql/mysqldb.py in dbapi(cls)
#     115     @classmethod
#     116     def dbapi(cls):
# --> 117         return __import__("MySQLdb")
#     118
#     119     def on_connect(self):
#
# ModuleNotFoundError: No module named 'MySQLdb'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Out:
#   File "<ipython-input-22-ff7f6e209581>", line 1
#     witch sqlalchemy
#                    ^
# SyntaxError: invalid syntax
