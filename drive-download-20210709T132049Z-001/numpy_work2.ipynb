# %%
names = ['spam', 'ham', 'eggs' ]
lens =[]
for name in names:
    lens.append(name)

lens
# Out:
# ['spam', 'ham', 'eggs']

# %%
lens('spam')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-caf03f64e471> in <module>()
# ----> 1 lens('spam')
#
# TypeError: 'list' object is not callable

# %%
import numpy as np
a = np.full((1, 5), np.e).T.ravel()
a
# Out:
# array([2.71828183, 2.71828183, 2.71828183, 2.71828183, 2.71828183])

# %%
import numpy as np
a = np.full((1, 5), np.e)
a
# Out:
# array([[2.71828183, 2.71828183, 2.71828183, 2.71828183, 2.71828183]])

# %%
import numpy as np
a = np.full(1, 5).T.ravel
a
# Out:
# <function ndarray.ravel>

# %%
b = np.linspace(0, 1, 5)
b
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
a = np.full((1, 5), np.e).T.ravel()
b = np.linspace(0, 1, 5)
c = np.hstack([a, b])
c
# Out:
# array([2.71828183, 2.71828183, 2.71828183, 2.71828183, 2.71828183,
#        0.        , 0.25      , 0.5       , 0.75      , 1.        ])

# %%
import numpy as np

a = np.array([[0,1],
              [2,3]])

b = np.array([[0,1],[3,4]])

a*b
# Out:
# array([[ 0,  1],
#        [ 6, 12]])

# %%
import numpy as np

a = np.array([[0,1,10],[0,1,10]])
a2 = a.reshape(2,3)
a * a2
# Out:
# array([[  0,   1, 100],
#        [  0,   1, 100]])

# %%
a
# Out:
# array([[ 0,  1, 10],
#        [ 0,  1, 10]])

# %%
a2
# Out:
# array([[ 0,  1],
#        [10,  0],
#        [ 1, 10]])

# %%
import numpy as np

A = np.eye(3)
B = np.count_nonzero(A)
C = np.sum(A)

# %%
B
# Out:
# 3
