# %%
names = ['spam','ham','egg']

# %%
lens = []

# %%
for name in names:
  lens.append(len(name))

# %%
lens
# Out:
# [4, 3, 3]

# %%
[len(name) for name in names]
# Out:
# [4, 3, 3]

# %%
{len(name) for name in names}
# Out:
# {3, 4}

# %%
{name: len(name) for name in names}
# Out:
# {'egg': 3, 'ham': 3, 'spam': 4}

# %%
s1 = 'hello python'

# %%
s1.upper(), s1.lower(), s1.title()
# Out:
# ('HELLO PYTHON', 'hello python', 'Hello Python')

# %%
s1.replace('hello', 'hi')
# Out:
# 'hi python'

# %%
s2 = ' spam ham eggs '

# %%
s2.split()
# Out:
# ['spam', 'ham', 'eggs']

# %%
lang, num, name = 'python', 10, 'takanory'

# %%
'{}は{}がすきです'.format(lang,name)
# Out:
# 'pythonはtakanoryがすきです'

# %%
import re

# %%
prog = re.compile('(P(yth|l)|Z)o[pn]e?')

# %%
prog.search('Python')
# Out:
# <_sre.SRE_Match object; span=(0, 6), match='Python'>

# %%
from datetime import datetime, date
datetime.now()
# Out:
# datetime.datetime(2021, 1, 7, 11, 7, 59, 408203)

# %%
date.today()
# Out:
# datetime.date(2021, 1, 7)

# %%
datetime.now().isoformat()
# Out:
# '2021-01-07T11:08:59.579556'

# %%
date.today().strftime('%Y年%m月%d日')
# Out:
# '2021年01月07日'

# %%
datetime.strptime('2018年7月11日', '%Y年%m月%d日')
# Out:
# datetime.datetime(2018, 7, 11, 0, 0)
