# %%
import numpy as np

A = np.array([[0, 1, 2, 3, 4]])
B = np.full((1, 5), 1)
A[A>=B]
# Out:
# array([1, 2, 3, 4])

# %%
B
# Out:
# array([[1, 1, 1, 1, 1]])

# %%
np.ones((3,2))
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.]])

# %%
import copy 

A = [1,2,3]
B = A.copy()
A.append(4)
B
# Out:
# [1, 2, 3]

# %%
A.append(4)
A
# Out:
# [1, 2, 3, 4, 4, 4]

# %%
import numpy as np

a = np.array([[0,1,10],[0,1,10]])
b = a.copy()
a = a.reshape(3,2)
np.dot(a, b)
# Out:
# array([[  0,   1,  10],
#        [  0,  10, 100],
#        [  0,  11, 110]])

# %%
np.multiply(a,b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-64b569d94410> in <module>()
# ----> 1 np.multiply(a,b)
#
# ValueError: operands could not be broadcast together with shapes (3,2) (2,3)
