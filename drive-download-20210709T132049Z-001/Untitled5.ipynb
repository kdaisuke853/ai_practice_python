# %%
import numpy as np

# %%
import numpy as np

A = np.linspace(0, 2, 5)
B = np.diff(A)*2
B
# Out:
# array([1., 1., 1., 1.])

# %%
A
# Out:
# array([0. , 0.5, 1. , 1.5, 2. ])

# %%
import numpy as np

A = np.linspace(0, 2, 5)
B = np.diff(A)*2
B == np.ones(4)
